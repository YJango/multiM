# %% [markdown]
# # re try

# %%
traindf = pd.read_csv(PATH+'firstimpressionV2/train/text_and_labels.csv')
testdf = pd.read_csv(PATH+'firstimpressionV2/test/text_and_labels.csv')
validf = pd.read_csv(PATH+'firstimpressionV2/vali/text_and_labels.csv')

# %%
p = r"\'why"
pattern = re.compile(p)
matches = pattern.finditer(lines)
i=0
for m in matches:
    print(m)
    i+=1
print(i)
# Out:
# <_sre.SRE_Match object; span=(60244, 60248), match="'why">
# 1

# %%
lines[60200:60300]
# Out:
# "me, everyday you wake up, you remember that 'why', and you apply it. Turn on your television\nThis ta"

# %%
word_tokenize(lines[60200:60300])
# Out:
# ['me',
#  ',',
#  'everyday',
#  'you',
#  'wake',
#  'up',
#  ',',
#  'you',
#  'remember',
#  'that',
#  "'why",
#  "'",
#  ',',
#  'and',
#  'you',
#  'apply',
#  'it',
#  '.',
#  'Turn',
#  'on',
#  'your',
#  'television',
#  'This',
#  'ta']

# %%
textfilter(lines)[345200:345300]
# Out:
# "o be...\noh my god, and  inaudible  coming back to 'murica. i do nt  know. like  inaudible  is in ame"

# %%
with open('/USERS/d8182103/firstimpressionV2/tfrecord/text/train/train.txt') as f:
    lines = f.read()
pattern = re.compile(r'\[[^:]*(\d\d:\d\d|\d\d:\d\d:\d\d)[\s\w\d]*\]')
matches = pattern.finditer(lines)
i=0
for m in matches:
    print(m)
    i+=1
print(i)
# Out:
# <_sre.SRE_Match object; span=(2120, 2136), match='[Sting 00:00:13]'>
# <_sre.SRE_Match object; span=(5133, 5153), match='[inaudible 00:00:30]'>
# <_sre.SRE_Match object; span=(7894, 7914), match='[inaudible 00:00:11]'>
# <_sre.SRE_Match object; span=(8706, 8720), match='[ink 00:00:15]'>
# <_sre.SRE_Match object; span=(11158, 11182), match='[P50 challenge 00:00:01]'>
# <_sre.SRE_Match object; span=(11227, 11245), match='[Matthew 00:00:04]'>
# <_sre.SRE_Match object; span=(13479, 13497), match='[plasocemia 00:10]'>
# <_sre.SRE_Match object; span=(13967, 13987), match='[inaudible 00:00:35]'>
# <_sre.SRE_Match object; span=(14020, 14047), match='[foreign language 00:00:38]'>
# <_sre.SRE_Match object; span=(14883, 14903), match='[inaudible 00:00:12]'>
# <_sre.SRE_Match object; span=(16716, 16736), match='[inaudible 00:00:59]'>
# <_sre.SRE_Match object; span=(16930, 16950), match='[inaudible 00:00:15]'>
# <_sre.SRE_Match object; span=(20645, 20665), match='[inaudible 00:00:45]'>
# ...

# %%
pattern = re.compile(r'\[[\s\w\d]+(\d\d:\d\d|\d\d:\d\d:\d\d)[\s\w\d]*\]')
matches = pattern.finditer(lines)
i=0
for m in matches:
    print(m)
    i+=1
print(i)

# %%
pattern = re.compile(r"M[r|s|rs]")
matches = pattern.finditer(lines)
i=0
for m in matches:
    print(m)
    i+=1
print(i)
# Out:
# <_sre.SRE_Match object; span=(16836, 16838), match='Mr'>
# <_sre.SRE_Match object; span=(513634, 513636), match='Mr'>
# <_sre.SRE_Match object; span=(733124, 733126), match='Mr'>
# <_sre.SRE_Match object; span=(1046313, 1046315), match='Mr'>
# <_sre.SRE_Match object; span=(1057923, 1057925), match='Mr'>
# <_sre.SRE_Match object; span=(1109419, 1109421), match='Mr'>
# <_sre.SRE_Match object; span=(1191267, 1191269), match='Mr'>
# <_sre.SRE_Match object; span=(1224871, 1224873), match='Mr'>
# 8

# %%
pattern = re.compile(r' \d\.*\d*[ |,]\d*')
matches = pattern.finditer(lines)
i=0
for m in matches:
    print(m)
    i+=1
print(i)
# Out:
# <_sre.SRE_Match object; span=(991, 995), match=' 30 '>
# <_sre.SRE_Match object; span=(3741, 3745), match=' 11 '>
# <_sre.SRE_Match object; span=(4905, 4909), match=' 15 '>
# <_sre.SRE_Match object; span=(4911, 4915), match=' 25 '>
# <_sre.SRE_Match object; span=(8655, 8659), match=' 10 '>
# <_sre.SRE_Match object; span=(10104, 10108), match=' 10 '>
# <_sre.SRE_Match object; span=(10407, 10412), match=' 400 '>
# <_sre.SRE_Match object; span=(10414, 10419), match=' 500 '>
# <_sre.SRE_Match object; span=(11099, 11105), match=' 4,000'>
# <_sre.SRE_Match object; span=(14564, 14572), match=' 150,000'>
# <_sre.SRE_Match object; span=(19441, 19445), match=' 21 '>
# <_sre.SRE_Match object; span=(21164, 21168), match=' 30 '>
# <_sre.SRE_Match object; span=(21170, 21174), match=' 40 '>
# <_sre.SRE_Match object; span=(21356, 21360), match=' 12 '>
# <_sre.SRE_Match object; span=(28994, 28999), match=' 800 '>
# <_sre.SRE_Match object; span=(29046, 29051), match=' 750 '>
# ...
